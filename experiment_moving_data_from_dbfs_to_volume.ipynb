# %%
# recursively copy dbfs:/tmp/imagery/sentinel-2-l2a to /Volumes/space-force-demo-dev/temp/imagery/sentinel-2-l2a
dbutils.fs.cp("dbfs:/tmp/imagery/sentinel-2-l2a", "dbfs:/Volumes/space-force-demo-dev/temp/imagery/sentinel-2-l2a", True)
